# %%
import requests
import bs4
import re
import sys

# %%
url = 'https://www.lyrics.com/artist/OneRepublic/770910'
#response = requests.get(url)

# %%
#soup = bs4.BeautifulSoup(response.text)
#links = soup.select('div.video-summary-data a[href^=/video]')

# %%
def get_lyrics_urls():
    response = requests.get(url)
    soup = bs4.BeautifulSoup(response.text)
    return [a.get('href') for a in soup.find_all('a', href=True)]

print(get_lyrics_urls())
# Out:
# ['login.php', 'https://www.abbreviations.com/', 'https://www.anagrams.net/', 'https://www.biographies.net/', 'https://www.calculators.net/', 'https://www.convert.net/', 'https://www.definitions.net/', 'https://www.grammar.com/', 'https://www.literature.com/', 'https://www.lyrics.com/', 'https://www.phrases.com/', 'https://www.poetry.com/', 'https://www.quotes.net/', 'https://www.references.net/', 'https://www.rhymes.net/', 'https://www.scripts.com/', 'https://www.symbols.com/', 'https://www.synonyms.com/', 'https://www.uszip.com/', '/artists/0', '/artists/A', '/artists/B', '/artists/C', '/artists/D', '/artists/E', '/artists/F', '/artists/G', '/artists/H', '/artists/I', '/artists/J', '/artists/K', '/artists/L', '/artists/M', '/artists/N', '/artists/O', '/artists/P', '/artists/Q', '/artists/R', '/artists/S', '/artists/T', '/artists/U', '/artists/V', '/artists/W', '/artists/X', '/artists/Y', '/artists/Z', '/justadded', 'random.php', 'artist/OneRepublic/770910', 'artist/OneRepublic/77091
# ...

# %%
def get_lyrics(lyrics_url):
    lyrics = {}
    response = requests.get(url + lyrics_url)
    soup = bs4.BeautifulSoup(response.get.content, 'lxml').text
    lyrics_url = str(soup_song.find('pre', attrs={'id': 'lyric-body-text'}))
        
    with open('./songs/' + artist_name.replace(' ', '_') + '_' + str(i).zfill(num_len) + '.txt', 'w') as f:
                #zfill(num_len) makes sure there are enough leading 0's before the number to sort files easily.
        f.writelines(lyrics)
        lyric

# %%
lyrics
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-53a0be6e2570> in <module>
# ----> 1 lyrics
#
# NameError: name 'lyrics' is not defined
