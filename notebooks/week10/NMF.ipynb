# %% [markdown]
# # NMF (Non-Negative Matrix Factorization)

# %% [markdown]
# ---

# %% [markdown]
# ## 0) Imports and Loading Data

# %%
import pandas as pd
import numpy as np

# NMF
from sklearn.decomposition import NMF

# %%
R = pd.read_csv('movie_ratings.csv', usecols=list(range(1,12)), index_col=0, 
               skiprows=1, nrows=13)
R
# Out:
#           Night on Earth  Der Clou / The Sting  \
# user
# Stefan               5.0                   NaN
# Thomas               NaN                   5.0
# Filipe               NaN                   NaN
# Marija               5.0                   NaN
# Andreas              NaN                   NaN
# Daniel               5.0                   2.0
# Matthias             4.0                   NaN
# Jana                 NaN                   NaN
# Homa                 NaN                   NaN
# Saskia               NaN                   NaN
# Benedict             NaN                   NaN
# Xiaohui              NaN                   NaN
# Burcu                NaN                   NaN
#
#           Me and You and Everyone We Know  La vita è bella  Before Sunset  \
# user
# Stefan                                NaN              NaN            NaN
# Thomas                                NaN              4.0            2.0
# Filipe                                5.0              5.0            4.0
# Marija                                5.0              3.0            5.0
# Andreas                               NaN              NaN            NaN
# Daniel                                4.0              3.0            4.0
# Matthias                              NaN              4.0            NaN
# Jana                                  NaN              NaN            NaN
# Homa                                  NaN              5.0            5.0
# Saskia                                NaN              NaN            NaN
# Benedict                              NaN              5.0            NaN
# Xiaohui                               NaN              5.0            4.0
# Burcu                                 NaN              NaN            NaN
#
#           The Last King of Scotland  The Mauritanian  \
# user
# Stefan                          NaN              NaN
# Thomas                          4.0              NaN
# Filipe                          NaN              NaN
# Marija                          3.0              NaN
# Andreas                         5.0              NaN
# Daniel                          4.0              5.0
# Matthias                        3.0              NaN
# Jana                            NaN              NaN
# Homa                            NaN              NaN
# Saskia                          NaN              NaN
# Benedict                        3.0              NaN
# Xiaohui                         NaN              NaN
# Burcu                           NaN              NaN
#
#           One Flew Over the Cuckoo's Nest  Lullaby for Pi  twelve monkeys
# user
# Stefan                                5.0             NaN             NaN
# Thomas                                3.0             NaN             NaN
# Filipe                                4.0             NaN             5.0
# Marija                                4.0             NaN             2.0
# Andreas                               NaN             NaN             NaN
# Daniel                                4.0             NaN             5.0
# Matthias                              4.0             NaN             4.0
# Jana                                  5.0             NaN             4.0
# Homa                                  5.0             NaN             NaN
# Saskia                                NaN             5.0             NaN
# Benedict                              4.0             NaN             4.0
# Xiaohui                               NaN             NaN             4.0
# Burcu                                 5.0             NaN             NaN

# %%
R.shape
# Out:
# (13, 10)

# %% [markdown]
# ---

# %% [markdown]
# ## 1) Train NMF
# * Small n_components = ...
# * High n_components = ...

# %%
# Instantiate the nmf
nmf = NMF(n_components=4)

# %%
# As usual with scikit-learn Classes, we fit the nmf
nmf.fit(R)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d345e865590a> in <module>
#       1 # As usual with scikit-learn Classes, we fit the nmf
# ----> 2 nmf.fit(R)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py in fit(self, X, y, **params)
#    1340         self
#    1341         """
# -> 1342         self.fit_transform(X, **params)
#    1343         return self
#    1344
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py in fit_transform(self, X, y, W, H)
#    1305             Transformed data.
#    1306         """
# -> 1307         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#    1308                                 dtype=[np.float64, np.float32])
#    1309
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     661
#     662         if force_all_finite:
# --> 663             _assert_all_finite(array,
#     664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# ## 2) Deal with Missing Values
#
# - Scikit-Learn implementation of NMF is not able to deal with missing values. This was one of our main points of using it.
#
# **What can we do about it?**
#
# - Fill in the missing values
#     - Arbitrary value (0 or 3)
#     - Average over DataFrame
#     - Average per Column
#     - Average per Row
#     - Median
#
# - Use a different package; eg. surprise
# - Use my nmf_extension code

# %%
# This is not the best solution; try out different solutions
R = R.fillna(0)

# %%
R
# Out:
#           Night on Earth  Der Clou / The Sting  \
# user
# Stefan               5.0                   0.0
# Thomas               0.0                   5.0
# Filipe               0.0                   0.0
# Marija               5.0                   0.0
# Andreas              0.0                   0.0
# Daniel               5.0                   2.0
# Matthias             4.0                   0.0
# Jana                 0.0                   0.0
# Homa                 0.0                   0.0
# Saskia               0.0                   0.0
# Benedict             0.0                   0.0
# Xiaohui              0.0                   0.0
# Burcu                0.0                   0.0
#
#           Me and You and Everyone We Know  La vita è bella  Before Sunset  \
# user
# Stefan                                0.0              0.0            0.0
# Thomas                                0.0              4.0            2.0
# Filipe                                5.0              5.0            4.0
# Marija                                5.0              3.0            5.0
# Andreas                               0.0              0.0            0.0
# Daniel                                4.0              3.0            4.0
# Matthias                              0.0              4.0            0.0
# Jana                                  0.0              0.0            0.0
# Homa                                  0.0              5.0            5.0
# Saskia                                0.0              0.0            0.0
# Benedict                              0.0              5.0            0.0
# Xiaohui                               0.0              5.0            4.0
# Burcu                                 0.0              0.0            0.0
#
#           The Last King of Scotland  The Mauritanian  \
# user
# Stefan                          0.0              0.0
# Thomas                          4.0              0.0
# Filipe                          0.0              0.0
# Marija                          3.0              0.0
# Andreas                         5.0              0.0
# Daniel                          4.0              5.0
# Matthias                        3.0              0.0
# Jana                            0.0              0.0
# Homa                            0.0              0.0
# Saskia                          0.0              0.0
# Benedict                        3.0              0.0
# Xiaohui                         0.0              0.0
# Burcu                           0.0              0.0
#
#           One Flew Over the Cuckoo's Nest  Lullaby for Pi  twelve monkeys
# user
# Stefan                                5.0             0.0             0.0
# Thomas                                3.0             0.0             0.0
# Filipe                                4.0             0.0             5.0
# Marija                                4.0             0.0             2.0
# Andreas                               0.0             0.0             0.0
# Daniel                                4.0             0.0             5.0
# Matthias                              4.0             0.0             4.0
# Jana                                  5.0             0.0             4.0
# Homa                                  5.0             0.0             0.0
# Saskia                                0.0             5.0             0.0
# Benedict                              4.0             0.0             4.0
# Xiaohui                               0.0             0.0             4.0
# Burcu                                 5.0             0.0             0.0

# %%
nmf.fit(R)
# Out:
# /Users/stefanroth/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# NMF(n_components=4)

# %% [markdown]
# ## 3) Inspect the sub-matrices

# %%
R.shape
# Out:
# (13, 10)

# %%
# Extract Q
Q = nmf.components_
Q # Q should have a shape of ???
# Out:
# array([[0.        , 0.        , 1.04507656, 2.70406048, 2.44746186,
#         0.        , 0.        , 0.        , 0.        , 1.77846238],
#        [2.66275728, 0.        , 1.24888253, 0.        , 0.48978615,
#         0.70723996, 0.94825145, 1.85082355, 0.        , 0.69962965],
#        [0.13502739, 0.        , 0.        , 0.45001356, 0.        ,
#         0.        , 0.        , 2.79954125, 0.        , 0.6575245 ],
#        [0.        , 1.28723721, 0.        , 0.94728594, 0.        ,
#         2.42821088, 0.13595237, 0.        , 0.        , 0.09436887]])

# %%
# Make a DataFrame out of Q
Q = pd.DataFrame(nmf.components_, columns=R.columns)
Q
# Out:
#    Night on Earth  Der Clou / The Sting  Me and You and Everyone We Know  \
# 0        0.000000              0.000000                         1.045077
# 1        2.662757              0.000000                         1.248883
# 2        0.135027              0.000000                         0.000000
# 3        0.000000              1.287237                         0.000000
#
#    La vita è bella  Before Sunset  The Last King of Scotland  The Mauritanian  \
# 0         2.704060       2.447462                   0.000000         0.000000
# 1         0.000000       0.489786                   0.707240         0.948251
# 2         0.450014       0.000000                   0.000000         0.000000
# 3         0.947286       0.000000                   2.428211         0.135952
#
#    One Flew Over the Cuckoo's Nest  Lullaby for Pi  twelve monkeys
# 0                         0.000000             0.0        1.778462
# 1                         1.850824             0.0        0.699630
# 2                         2.799541             0.0        0.657525
# 3                         0.000000             0.0        0.094369

# %%
R.shape
# Out:
# (13, 10)

# %%
# Calculate P
P = nmf.transform(R)
P # We expect a shape of 13x4
# Out:
# array([[0.00000000e+00, 1.22435773e+00, 8.62779427e-01, 0.00000000e+00],
#        [4.29329937e-01, 0.00000000e+00, 9.56375656e-01, 2.15846918e+00],
#        [1.89660577e+00, 3.37954842e-01, 1.19922192e+00, 0.00000000e+00],
#        [1.18064519e+00, 1.95356107e+00, 0.00000000e+00, 3.95981457e-01],
#        [0.00000000e+00, 5.79166177e-02, 0.00000000e+00, 1.41901463e+00],
#        [1.11220072e+00, 2.29317922e+00, 0.00000000e+00, 1.04506959e+00],
#        [5.42491709e-01, 9.03520626e-01, 1.06081968e+00, 9.11164543e-01],
#        [1.44436228e-01, 3.69583550e-04, 1.91754297e+00, 0.00000000e+00],
#        [1.24445461e+00, 0.00000000e+00, 1.55996442e+00, 6.81867635e-02],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [7.82759351e-01, 0.00000000e+00, 1.60939980e+00, 1.11774697e+00],
#        [1.71333327e+00, 0.00000000e+00, 9.05799962e-02, 4.64010982e-02],
#        [0.00000000e+00, 0.00000000e+00, 1.64862879e+00, 0.00000000e+00]])

# %%
# Make a DataFrame out of P
P = pd.DataFrame(nmf.transform(R), index=R.index)
P
# Out:
#                  0         1         2         3
# user
# Stefan    0.000000  1.224358  0.862779  0.000000
# Thomas    0.429330  0.000000  0.956376  2.158469
# Filipe    1.896606  0.337955  1.199222  0.000000
# Marija    1.180645  1.953561  0.000000  0.395981
# Andreas   0.000000  0.057917  0.000000  1.419015
# Daniel    1.112201  2.293179  0.000000  1.045070
# Matthias  0.542492  0.903521  1.060820  0.911165
# Jana      0.144436  0.000370  1.917543  0.000000
# Homa      1.244455  0.000000  1.559964  0.068187
# Saskia    0.000000  0.000000  0.000000  0.000000
# Benedict  0.782759  0.000000  1.609400  1.117747
# Xiaohui   1.713333  0.000000  0.090580  0.046401
# Burcu     0.000000  0.000000  1.648629  0.000000

# %%
# Look at the reconstruction error
nmf.reconstruction_err_
# Out:
# 11.858954706043287

# %% [markdown]
# ## 3) Reconstruct the original matrix

# %%
# Look at the original matrix R
R.head()

# %%
Q.shape
# Out:
# (4, 10)

# %%
P.shape
# Out:
# (13, 4)

# %%
# Calculate R_hat
R_hat = pd.DataFrame(np.dot(P, Q), columns=R.columns, index=R.index)
round(R_hat, 2)
# Out:
#           Night on Earth  Der Clou / The Sting  \
# user
# Stefan              3.38                  0.00
# Thomas              0.13                  2.78
# Filipe              1.06                  0.00
# Marija              5.20                  0.51
# Andreas             0.15                  1.83
# Daniel              6.11                  1.35
# Matthias            2.55                  1.17
# Jana                0.26                  0.00
# Homa                0.21                  0.09
# Saskia              0.00                  0.00
# Benedict            0.22                  1.44
# Xiaohui             0.01                  0.06
# Burcu               0.22                  0.00
#
#           Me and You and Everyone We Know  La vita è bella  Before Sunset  \
# user
# Stefan                               1.53             0.39           0.60
# Thomas                               0.45             3.64           1.05
# Filipe                               2.40             5.67           4.81
# Marija                               3.67             3.57           3.85
# Andreas                              0.07             1.34           0.03
# Daniel                               4.03             4.00           3.85
# Matthias                             1.70             2.81           1.77
# Jana                                 0.15             1.25           0.35
# Homa                                 1.30             4.13           3.05
# Saskia                               0.00             0.00           0.00
# Benedict                             0.82             3.90           1.92
# Xiaohui                              1.79             4.72           4.19
# Burcu                                0.00             0.74           0.00
#
#           The Last King of Scotland  The Mauritanian  \
# user
# Stefan                         0.87             1.16
# Thomas                         5.24             0.29
# Filipe                         0.24             0.32
# Marija                         2.34             1.91
# Andreas                        3.49             0.25
# Daniel                         4.16             2.32
# Matthias                       2.85             0.98
# Jana                           0.00             0.00
# Homa                           0.17             0.01
# Saskia                         0.00             0.00
# Benedict                       2.71             0.15
# Xiaohui                        0.11             0.01
# Burcu                          0.00             0.00
#
#           One Flew Over the Cuckoo's Nest  Lullaby for Pi  twelve monkeys
# user
# Stefan                               4.68             0.0            1.42
# Thomas                               2.68             0.0            1.60
# Filipe                               3.98             0.0            4.40
# Marija                               3.62             0.0            3.50
# Andreas                              0.11             0.0            0.17
# Daniel                               4.24             0.0            3.68
# Matthias                             4.64             0.0            2.38
# Jana                                 5.37             0.0            1.52
# Homa                                 4.37             0.0            3.25
# Saskia                               0.00             0.0            0.00
# Benedict                             4.51             0.0            2.56
# Xiaohui                              0.25             0.0            3.11
# Burcu                                4.62             0.0            1.08

# %% [markdown]
# ---

# %% [markdown]
# ## 4) Make a prediction based on new user input

# %%
# Create a dictionary for a new user
new_user_input = {'Before Sunset': 2, 'twelve monkeys': 4} # Because you will receive your Data from the web app as json

# %%
new_user_input
# Out:
# {'Before Sunset': 2, 'twelve monkeys': 4}

# %%
# Convert it to a pd.DataFrame
new_user = pd.DataFrame(new_user_input, index=['Paul'], columns=R.columns)
new_user
# Out:
#      Night on Earth Der Clou / The Sting Me and You and Everyone We Know  \
# Paul            NaN                  NaN                             NaN
#
#      La vita è bella  Before Sunset The Last King of Scotland The Mauritanian  \
# Paul             NaN              2                       NaN             NaN
#
#      One Flew Over the Cuckoo's Nest Lullaby for Pi  twelve monkeys
# Paul                             NaN            NaN               4

# %%
#Prediction step 1 - generate user_P 
user_P = nmf.transform(new_user.fillna(0))
user_P
# Out:
# array([[0.66054021, 0.05595301, 0.08457801, 0.        ]])

# %%
#new user R - reconstruct R but for this new user only
user_R = pd.DataFrame(np.dot(user_P, Q), columns=R.columns, index=['Paul'])
user_R
# Out:
#       Night on Earth  Der Clou / The Sting  Me and You and Everyone We Know  \
# Paul         0.16041                   0.0                         0.760194
#
#       La vita è bella  Before Sunset  The Last King of Scotland  \
# Paul         1.824202       1.644052                   0.039572
#
#       The Mauritanian  One Flew Over the Cuckoo's Nest  Lullaby for Pi  \
# Paul         0.053058                         0.340339             0.0
#
#       twelve monkeys
# Paul        1.269504

# %%
user_R.loc[:,list(set(user_R.columns).difference(set(new_user_input.keys())))]
# Out:
#       One Flew Over the Cuckoo's Nest  The Mauritanian  Lullaby for Pi  \
# Paul                         0.340339         0.053058             0.0
#
#       Der Clou / The Sting  Me and You and Everyone We Know  Night on Earth  \
# Paul                   0.0                         0.760194         0.16041
#
#       La vita è bella  The Last King of Scotland
# Paul         1.824202                   0.039572

# %%
# Remove movies that have already been seen
recommendations = user_R.loc[:,list(set(user_R.columns).difference(set(new_user_input.keys())))]
recommendations
# Out:
#       One Flew Over the Cuckoo's Nest  The Mauritanian  Lullaby for Pi  \
# Paul                         0.340339         0.053058             0.0
#
#       Der Clou / The Sting  Me and You and Everyone We Know  Night on Earth  \
# Paul                   0.0                         0.760194         0.16041
#
#       La vita è bella  The Last King of Scotland
# Paul         1.824202                   0.039572

# %%
# Sort the recomendations
recommendations.sort_values(axis=1, by='Paul', ascending=False)
# Out:
#       La vita è bella  Me and You and Everyone We Know  \
# Paul         1.824202                         0.760194
#
#       One Flew Over the Cuckoo's Nest  Night on Earth  The Mauritanian  \
# Paul                         0.340339         0.16041         0.053058
#
#       The Last King of Scotland  Lullaby for Pi  Der Clou / The Sting
# Paul                   0.039572             0.0                   0.0

# %% [markdown]
# ---

# %% [markdown]
# ## NMF_extension

# %%
pip install git+https://github.com/stefanfroth/nmf_extension
# Out:
# Collecting git+https://github.com/stefanfroth/nmf_extension
#   Cloning https://github.com/stefanfroth/nmf_extension to /private/var/folders/5k/g90jxpln6hd_1v980jl2q12w0000gn/T/pip-req-build-4w2uzy7f
#   Running command git clone -q https://github.com/stefanfroth/nmf_extension /private/var/folders/5k/g90jxpln6hd_1v980jl2q12w0000gn/T/pip-req-build-4w2uzy7f
# Requirement already satisfied: scikit-learn in /Users/stefanroth/anaconda3/lib/python3.8/site-packages (from nmf-extension==0.0.1) (0.24.1)
# Requirement already satisfied: joblib>=0.11 in /Users/stefanroth/anaconda3/lib/python3.8/site-packages (from scikit-learn->nmf-extension==0.0.1) (0.17.0)
# Requirement already satisfied: scipy>=0.19.1 in /Users/stefanroth/anaconda3/lib/python3.8/site-packages (from scikit-learn->nmf-extension==0.0.1) (1.5.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/stefanroth/anaconda3/lib/python3.8/site-packages (from scikit-learn->nmf-extension==0.0.1) (1.19.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/stefanroth/anaconda3/lib/python3.8/site-packages (from scikit-learn->nmf-extension==0.0.1) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nmf_extension.nmf import CustomNMF

# %%
R = pd.read_csv('movie_ratings.csv', usecols=list(range(1,12)), index_col=0, 
               skiprows=1, nrows=13)

# %%
custom_nmf = CustomNMF(n_components=4)

# %%
custom_nmf.fit(R)
# Out:
# CustomNMF(init='custom', n_components=4)

# %%
R_hat_custom = round(pd.DataFrame(np.dot(custom_nmf.transform(R), custom_nmf.components_), 
                            columns=R.columns, index=R.index), 2)
R_hat_custom
# Out:
#           Night on Earth  Der Clou / The Sting  \
# user
# Stefan              5.03                  5.35
# Thomas              3.13                  4.75
# Filipe              5.15                  3.51
# Marija              4.77                  4.04
# Andreas             4.98                  5.67
# Daniel              5.09                  2.17
# Matthias            4.17                  4.49
# Jana                4.75                  6.01
# Homa                5.89                  4.89
# Saskia              5.90                  4.26
# Benedict            4.75                  4.05
# Xiaohui             5.27                  4.22
# Burcu               5.80                  4.76
#
#           Me and You and Everyone We Know  La vita è bella  Before Sunset  \
# user
# Stefan                               5.31             4.12           4.92
# Thomas                               4.38             4.44           2.53
# Filipe                               5.16             4.93           3.67
# Marija                               4.68             3.21           4.65
# Andreas                              5.38             4.37           4.87
# Daniel                               4.09             3.52           3.88
# Matthias                             4.54             3.93           3.78
# Jana                                 5.45             5.08           4.33
# Homa                                 6.00             5.24           4.87
# Saskia                               5.76             4.35           5.16
# Benedict                             5.01             4.48           3.81
# Xiaohui                              5.14             4.35           4.49
# Burcu                                5.59             4.95           4.88
#
#           The Last King of Scotland  The Mauritanian  \
# user
# Stefan                         4.16             4.35
# Thomas                         3.26             4.83
# Filipe                         3.95             6.78
# Marija                         3.26             4.02
# Andreas                        4.42             4.35
# Daniel                         3.64             5.01
# Matthias                       3.67             4.25
# Jana                           4.84             4.86
# Homa                           4.64             6.59
# Saskia                         3.90             6.08
# Benedict                       3.71             5.77
# Xiaohui                        4.17             5.32
# Burcu                          4.91             5.73
#
#           One Flew Over the Cuckoo's Nest  Lullaby for Pi  twelve monkeys
# user
# Stefan                               4.72            5.36            3.22
# Thomas                               3.22            3.95            3.13
# Filipe                               4.14            4.52            5.05
# Marija                               4.13            4.37            2.59
# Andreas                              4.82            5.60            3.43
# Daniel                               3.88            4.10            4.59
# Matthias                             3.92            4.54            3.26
# Jana                                 4.79            5.84            4.17
# Homa                                 5.06            5.60            4.90
# Saskia                               4.82            5.00            3.93
# Benedict                             4.06            4.48            4.05
# Xiaohui                              4.53            5.03            4.24
# Burcu                                5.08            5.79            5.03

# %% [markdown]
# # Next steps
# * download 100k movie lense dataset - all the data you'll need is in ratings.csv
# * work out a way to create a matrix with rows=users, columns=movies, values in the matrix= user_rating a for movie_id=1 etc
# * FOLLOW the steps in this notebook to create a trained NMF able to make predictions
